# %%
import pandas as pd 
dataset = pd.read_csv('user+data.csv')
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix
import pandas as pd

# %%
dataset = pd.read_csv('user+data.csv')
X= dataset.iloc[:,2:4].values
y = dataset.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler 
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.fit_transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Correct the typo in parameter name from n_neighbours to n_neighbors
classifier = KNeighborsClassifier(n_neighbors=5, metric="minkowski", p=2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_pred, y_test)

import seaborn as sns 
plt.figure(fig_size=(20,6))
sns.heatmap(cm)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 6
#       3 cm = confusion_matrix(y_pred, y_test)
#       5 import seaborn as sns
# ----> 6 plt.figure(fig_size=(20,6))
#       7 sns.heatmap(cm)
#
# File c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#     939 if fig_label:
#
# File c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py:465, in new_figure_manager(*args, **kwargs)
#     463 """Create a new figure manager instance."""
#     464 _warn_if_gui_out_of_main_thread()
# --> 465 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib_inline\backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\figure.py:2494, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2398 def __init__(self,
#    2399              figsize=None,
#    2400              dpi=None,
#    (...)
#    2410              **kwargs
#    2411              ):
#    2412     """
#    2413     Parameters
#    2414     ----------
#    (...)
#    2492         %(Figure:kwdoc)s
#    2493     """
# -> 2494     super().__init__(**kwargs)
#    2495     self.figure = self
#    2496     self._layout_engine = None
#
# File c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\figure.py:213, in FigureBase.__init__(self, **kwargs)
#     211 self.stale = True
#     212 self.suppressComposite = None
# --> 213 self.set(**kwargs)
#
# File c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\artist.py:1227, in Artist.set(self, **kwargs)
#    1223 def set(self, **kwargs):
#    1224     # docstring and signature are auto-generated via
#    1225     # Artist._update_set_signature_and_docstring() at the end of the
#    1226     # module.
# -> 1227     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Figure.set() got an unexpected keyword argument 'fig_size'
