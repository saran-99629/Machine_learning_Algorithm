# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix
 
dataset = pd.read_csv("user+data.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
X =dataset.iloc[:,2:4].values
y=dataset.iloc[:,4].values

# %%
X
# Out:
# array([[    19,  19000],
#        [    35,  20000],
#        [    26,  43000],
#        [    27,  57000],
#        [    19,  76000],
#        [    27,  58000],
#        [    27,  84000],
#        [    32, 150000],
#        [    25,  33000],
#        [    35,  65000],
#        [    26,  80000],
#        [    26,  52000],
#        [    20,  86000],
#        [    32,  18000],
#        [    18,  82000],
#        [    29,  80000],
#        [    47,  25000],
#        [    45,  26000],
#        [    46,  28000],
#        [    48,  29000],
#        [    45,  22000],
#        [    47,  49000],
#        [    48,  41000],
#        [    45,  22000],
#        [    46,  23000],
#        [    47,  20000],
#        [    49,  28000],
#        [    47,  30000],
#        [    29,  43000],
#        [    31,  18000],
#        [    31,  74000],
#        [    27, 137000],
#        [    21,  16000],
#        [    28,  44000],
#        [    27,  90000],
#        [    35,  27000],
#        [    33,  28000],
# ...

# %%
from sklearn.model_selection import train_test_split 
X_train ,X_test ,y_train ,y_test = train_test_split(X, y , test_size=0.25, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_pred, y_test)
cm
import matplotlib.pyplot as plt 
import seaborn as sns 

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", linewidth=.5)
plt.title('Confusion Matrix')
plt.xlabel('predicted')
plt.ylabel('Actal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 4
#       2 cm
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       6 plt.figure(figsize=(8,6))
#       7 sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", linewidth=.5)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have predicted values in y_pred and true values in y_test
# You need to replace y_pred and y_test with your actual variable names

# Example:
# y_pred = classifier.predict(X_test)
# y_test = y_test

# Compute confusion matrix
cm = confusion_matrix(y_pred, y_test)

# Plot the confusion matrix using seaborn and matplotlib
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
