# %%
import numpy as np 
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans 
from sklearn.datasets import make_blobs 
plt.rcParams['figure.figsize'] = (16, 9)

X,y = make_blobs(n_samples=800, n_features=3, centers =4)

# %%
X
# Out:
# array([[ 7.55974721,  0.80064882,  8.72557289],
#        [-5.34800237, -7.16904305,  1.01775605],
#        [-5.63981728, -7.74735526,  0.85326373],
#        ...,
#        [ 2.67164804, -1.2484686 ,  0.58247205],
#        [ 8.30423564,  0.05547381,  8.79124179],
#        [-5.51955723, -8.54718243,  1.41183051]])

# %%
from sklearn.cluster import KMeans 
wcss_list =[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss_list.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss_list)
plt.title("the elbow method")
plt.xlabel('number of clster')
plt.show()
